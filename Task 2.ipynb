# %% [markdown]
# ### import libraries

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os

import numpy as np

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, classification_report
import itertools

# %matplotlib inline

# %%
batch_size = 32  
num_classes = 10  
epochs = 100
data_augmentation = False

# %% [markdown]
# ### Import and preproces of data

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
print('x_train shape:', x_train.shape)
print('y_train shape:', y_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

x_train.shape: (50000, 32, 32, 3)
y_train.shape: (50000, 1)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 49s 0us/step
# x_train shape: (50000, 32, 32, 3)
# y_train shape: (50000, 1)
# 50000 train samples
# 10000 test samples

# %% [markdown]
# ### Distribution of data.

# %%
fig, axs = plt.subplots(1,2,figsize=(15,5)) 
# Count plot for training set
sns.countplot(y_train.ravel(), ax=axs[0])
axs[0].set_title('Distribution of training data')
axs[0].set_xlabel('Classes')
# Count plot for testing set
sns.countplot(y_test.ravel(), ax=axs[1])
axs[1].set_title('Distribution of Testing data')
axs[1].set_xlabel('Classes')
plt.show()
# Out:
# C:\Users\Lalit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Lalit\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Normalize the data. Before we need to connvert data type to float for computation.
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Convert class vectors to binary class matrices. This is called one hot encoding.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ### Defining the model architecture Using ConVnets

# %%
#define the convnet
model = Sequential()
# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# CONV => RELU => CONV => RELU => POOL => DROPOUT
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# FLATTERN => DENSE => RELU => DROPOUT
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
# a softmax classifier
model.add(Dense(num_classes))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model training

# %%
# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(learning_rate=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
history = None  # For recording the history of trainning process.
if not data_augmentation:
    print('Not using data augmentation.')
    history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        zca_epsilon=1e-06,  # epsilon for ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        # randomly shift images horizontally (fraction of total width)
        width_shift_range=0.1,
        # randomly shift images vertically (fraction of total height)
        height_shift_range=0.1,
        shear_range=0.,  # set range for random shear
        zoom_range=0.,  # set range for random zoom
        channel_shift_range=0.,  # set range for random channel shifts
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        cval=0.,  # value used for fill_mode = "constant"
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for feature-wise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit_generator(datagen.flow(x_train, y_train,
                                    batch_size=batch_size),
                                    epochs=epochs,
                                    validation_data=(x_test, y_test),
                                    workers=4)
# Out:
# Not using data augmentation.
# Epoch 1/100
# 1563/1563 [==============================] - 124s 80ms/step - loss: 1.8512 - accuracy: 0.3232 - val_loss: 1.5734 - val_accuracy: 0.4319
# Epoch 2/100
# 1563/1563 [==============================] - 124s 79ms/step - loss: 1.5266 - accuracy: 0.4438 - val_loss: 1.3742 - val_accuracy: 0.5020
# Epoch 3/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 1.3821 - accuracy: 0.5013 - val_loss: 1.2806 - val_accuracy: 0.5434
# Epoch 4/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 1.2894 - accuracy: 0.5375 - val_loss: 1.1970 - val_accuracy: 0.5759
# Epoch 5/100
# 1563/1563 [==============================] - 126s 81ms/step - loss: 1.2125 - accuracy: 0.5684 - val_loss: 1.1115 - val_accuracy: 0.6071
# Epoch 6/100
# 1563/1563 [==============================] - 116s 74ms/step - loss: 1.1468 - accuracy: 0.5937 - val_loss: 1.0669 - val_accuracy: 0.6282
# Epoch 7/100
# 1563/1563 [==============================] - 118s 75ms/step - loss: 1.0920 - accuracy: 0.6170 - val_loss: 1.0066 - val_accuracy: 0.6497
# Epoch 8/100
# 1563/1563 [==============================] - 118s 75ms/step - loss: 1.0432 - accuracy: 0.6324 - val_loss: 0.9712 - val_accuracy: 0.6639
# Epoch 9/100
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.9982 - accuracy: 0.6489 - val_loss: 0.9246 - val_accuracy: 0.6754
# Epoch 10/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.9596 - accuracy: 0.6639 - val_loss: 0.8923 - val_accuracy: 0.6892
# Epoch 11/100
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.9308 - accuracy: 0.6747 - val_loss: 0.8869 - val_accuracy: 0.6960
# Epoch 12/100
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.9031 - accuracy: 0.6838 - val_loss: 0.8468 - val_accuracy: 0.7082
# Epoch 13/100
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.8787 - accuracy: 0.6925 - val_loss: 0.8352 - val_accuracy: 0.7109
# Epoch 14/100
# 1563/1563 [==============================] - 118s 76ms/step - loss: 0.8554 - accuracy: 0.7032 - val_loss: 0.8121 - val_accuracy: 0.7221
# Epoch 15/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.8348 - accuracy: 0.7094 - val_loss: 0.8425 - val_accuracy: 0.7080
# Epoch 16/100
# 1563/1563 [==============================] - 115s 73ms/step - loss: 0.8132 - accuracy: 0.7164 - val_loss: 0.7891 - val_accuracy: 0.7297
# Epoch 17/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.7999 - accuracy: 0.7262 - val_loss: 0.8015 - val_accuracy: 0.7250
# Epoch 18/100
# 1563/1563 [==============================] - 114s 73ms/step - loss: 0.7896 - accuracy: 0.7281 - val_loss: 0.7600 - val_accuracy: 0.7426
# Epoch 19/100
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.7750 - accuracy: 0.7307 - val_loss: 0.7579 - val_accuracy: 0.7403
# Epoch 20/100
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.7648 - accuracy: 0.7348 - val_loss: 0.7393 - val_accuracy: 0.7489
# Epoch 21/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.7574 - accuracy: 0.7403 - val_loss: 0.7354 - val_accuracy: 0.7512
# Epoch 22/100
# 1563/1563 [==============================] - 126s 81ms/step - loss: 0.7451 - accuracy: 0.7432 - val_loss: 0.7293 - val_accuracy: 0.7496
# Epoch 23/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0
100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6254 - accuracy: 0.7910 - val_loss: 0.6545 - val_accuracy: 0.7873
# Epoch 66/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.6287 - accuracy: 0.7904 - val_loss: 0.6347 - val_accuracy: 0.7906
# Epoch 67/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6237 - accuracy: 0.7902 - val_loss: 0.7116 - val_accuracy: 0.7646
# Epoch 68/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6269 - accuracy: 0.7908 - val_loss: 0.7371 - val_accuracy: 0.7722
# Epoch 69/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6263 - accuracy: 0.7905 - val_loss: 0.6685 - val_accuracy: 0.7809
# Epoch 70/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6242 - accuracy: 0.7912 - val_loss: 0.7306 - val_accuracy: 0.7714
# Epoch 71/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.6231 - accuracy: 0.7942 - val_loss: 0.6577 - val_accuracy: 0.7847
# Epoch 72/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6287 - accuracy: 0.7909 - val_loss: 0.6724 - val_accuracy: 0.7771
# Epoch 73/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6280 - accuracy: 0.7899 - val_loss: 0.6566 - val_accuracy: 0.7850
# Epoch 74/100
# 1563/1563 [==============================] - 135s 87ms/step - loss: 0.6252 - accuracy: 0.7935 - val_loss: 0.6689 - val_accuracy: 0.7796
# Epoch 75/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6207 - accuracy: 0.7929 - val_loss: 0.6938 - val_accuracy: 0.7756
# Epoch 76/100
# 1563/1563 [==============================] - 135s 87ms/step - loss: 0.6211 - accuracy: 0.7911 - val_loss: 0.6748 - val_accuracy: 0.7793
# Epoch 77/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.6284 - accuracy: 0.7910 - val_loss: 0.7015 - val_accuracy: 0.7814
# Epoch 78/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.6282 - accuracy: 0.7912 - val_loss: 0.7194 - val_accuracy: 0.7711
# Epoch 79/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6278 - accuracy: 0.7906 - val_loss: 0.6710 - val_accuracy: 0.7816
# Epoch 80/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.6277 - accuracy: 0.7926 - val_loss: 0.6709 - val_accuracy: 0.7833
# Epoch 81/100
# 1563/1563 [==============================] - 139s 89ms/step - loss: 0.6214 - accuracy: 0.7929 - val_loss: 0.6688 - val_accuracy: 0.7867
# Epoch 82/100
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.6298 - accuracy: 0.7914 - val_loss: 0.7048 - val_accuracy: 0.7771
# Epoch 83/100
# 1563/1563 [==============================] - 139s 89ms/step - loss: 0.6187 - accuracy: 0.7939 - val_loss: 0.6787 - val_accuracy: 0.7796
# Epoch 84/100
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.6249 - accuracy: 0.7925 - val_loss: 0.6457 - val_accuracy: 0.7929
# Epoch 85/100
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.6255 - accuracy: 0.7924 - val_loss: 0.6828 - val_accuracy: 0.7767
# Epoch 86/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.6213 - accuracy: 0.7940 - val_loss: 0.6798 - val_accuracy: 0.7792
# Epoch 87/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6304 - accuracy: 0.7906 - val_loss: 0.6769 - val_accuracy: 0.7890
# Epoch 88/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 0.6238 - accuracy: 0.7934 - val_loss: 0.6785 - val_accuracy: 0.7789
# Epoch 89/100
# 1563/1563 [==============================] - 137s 87ms/step - loss: 0.6266 - accuracy: 0.7931 - val_loss: 0.8003 - val_accuracy: 0.7734
# Epoch 90/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.6254 - accuracy: 0.7921 - val_loss: 0.6390 - val_accuracy: 0.7908
# Epoch 91/100
# 1563/1563 [==============================] - 137s 88ms/step - loss: 0.6257 - accuracy: 0.7921 - val_loss: 0.7349 - val_accuracy: 0.7694
# Epoch 92/100
# 1563/1563 [==============================] - 135s 87ms/step - loss: 0.6264 - accuracy: 0.7923 - val_loss: 0.6811 - val_accuracy: 0.7721
# Epoch 93/100
# 1563/1563 [==============================] - 135s 87ms/step - loss: 0.6232 - accuracy: 0.7939 - val_loss: 0.7138 - val_accuracy: 0.7701
# Epoch 94/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.6228 - accuracy: 0.7955 - val_loss: 0.7854 - val_accuracy: 0.7492
# Epoch 95/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.6257 - accuracy: 0.7949 - val_loss: 0.6801 - val_accuracy: 0.7804
# Epoch 96/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.6219 - accuracy: 0.7956 - val_loss: 0.8949 - val_accuracy: 0.7773
# Epoch 97/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.6211 - accuracy: 0.7945 - val_loss: 0.7253 - val_accuracy: 0.7694
# Epoch 98/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.6252 - accuracy: 0.7934 - val_loss: 0.6725 - val_accuracy: 0.7858
# Epoch 99/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.6283 - accuracy: 0.7926 - val_loss: 0.9249 - val_accuracy: 0.7455
# Epoch 100/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.6232 - accuracy: 0.7937 - val_loss: 0.7481 - val_accuracy: 0.7584

# %% [markdown]
# ### Evaluate the Model

# %% [markdown]
# # Training and validation curves.

# %%
def plotmodelhistory(history): 
    fig, axs = plt.subplots(1,2,figsize=(15,5)) 
    # summarize history for accuracy
    axs[0].plot(history.history['accuracy']) 
    axs[0].plot(history.history['val_accuracy']) 
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy') 
    axs[0].set_xlabel('Epoch')
    axs[0].legend(['train', 'validate'], loc='upper left')
    # summarize history for loss
    axs[1].plot(history.history['loss']) 
    axs[1].plot(history.history['val_loss']) 
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss') 
    axs[1].set_xlabel('Epoch')
    axs[1].legend(['train', 'validate'], loc='upper left')
    plt.show()

# list all data in history
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plotmodelhistory(history)

# %% [markdown]
# ### Score trained model and prediction

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])

# make prediction.
pred = model.predict(x_test)
# Out:
# 313/313 [==============================] - 4s 11ms/step - loss: 0.7481 - accuracy: 0.7584
# Test loss: 0.7480694055557251
# Test accuracy: 0.758400022983551

# %% [markdown]
# ### Confusion Matrix

# %%
def heatmap(data, row_labels, col_labels, ax=None, cbar_kw={}, cbarlabel="", **kwargs):
    """
    Create a heatmap from a numpy array and two lists of labels.
    """
    if not ax:
        ax = plt.gca()

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)

    # Create colorbar
    cbar = ax.figure.colorbar(im, ax=ax, **cbar_kw)
    cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

    # Let the horizontal axes labeling appear on top.
    ax.tick_params(top=True, bottom=False,
                   labeltop=True, labelbottom=False)
    # We want to show all ticks...
    ax.set_xticks(np.arange(data.shape[1]))
    ax.set_yticks(np.arange(data.shape[0]))
    # ... and label them with the respective list entries.
    ax.set_xticklabels(col_labels)
    ax.set_yticklabels(row_labels)
    
    ax.set_xlabel('Predicted Label') 
    ax.set_ylabel('True Label')
    
    return im, cbar

def annotate_heatmap(im, data=None, fmt="d", threshold=None):
    """
    A function to annotate a heatmap.
    """
    # Change the text's color depending on the data.
    texts = []
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            text = im.axes.text(j, i, format(data[i, j], fmt), horizontalalignment="center",
                                 color="white" if data[i, j] > thresh else "black")
            texts.append(text)

    return texts

# %%
labels = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(pred, axis=1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test, axis=1)
# Errors are difference between predicted labels and true labels
errors = (Y_pred_classes - Y_true != 0)

Y_pred_classes_errors = Y_pred_classes[errors]
Y_pred_errors = pred[errors]
Y_true_errors = Y_true[errors]
X_test_errors = x_test[errors]

cm = confusion_matrix(Y_true, Y_pred_classes) 
thresh = cm.max() / 2.

fig, ax = plt.subplots(figsize=(12,12))
im, cbar = heatmap(cm, labels, labels, ax=ax,
                   cmap=plt.cm.Blues, cbarlabel="count of predictions")
texts = annotate_heatmap(im, data=cm, threshold=thresh)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Classification report

# %%
print(classification_report(Y_true, Y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.82      1000
#            1       0.87      0.90      0.89      1000
#            2       0.56      0.74      0.64      1000
#            3       0.74      0.47      0.58      1000
#            4       0.67      0.76      0.71      1000
#            5       0.74      0.66      0.70      1000
#            6       0.63      0.94      0.75      1000
#            7       0.93      0.67      0.78      1000
#            8       0.89      0.86      0.88      1000
#            9       0.94      0.79      0.86      1000
#
#     accuracy                           0.76     10000
#    macro avg       0.78      0.76      0.76     10000
# weighted avg       0.78      0.76      0.76     10000

# %% [markdown]
# ### Check the predictions

# %%
R = 5
C = 5
fig, axes = plt.subplots(R, C, figsize=(12,12))
axes = axes.ravel()

for i in np.arange(0, R*C):
    axes[i].imshow(x_test[i])
    axes[i].set_title("True: %s \nPredict: %s" % (labels[Y_true[i]], labels[Y_pred_classes[i]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)
